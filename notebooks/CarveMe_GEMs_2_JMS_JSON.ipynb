# %% [markdown]
# # Porting genome scale metabolic models for metabolomics
# - from CarveMe
#
# **source**
# - https://github.com/cdanielmachado/carveme
#
# **Use cobra to parse SBML models whereas applicable**
#
# Not all models comply with the formats in cobra. Models from USCD and Thiele labs should comply.
#
# **Base our code on metDataModel**
#
# Each model needs a list of Reactions, list of Pathways, and a list of Compounds.
# It's important to include with Compounds with all linked identifiers to other DBs (HMDB, PubChem, etc), and with formulae (usually charged form in these models) when available.
# We can alwasy update the data later. E.g. the neural formulae can be inferred from charged formula or retrieved from public metabolite database (e.g., HMDB) if linked.
# Save in Python pickle and in JSON.
#
# **No compartmentalization**
# - After decompartmentalization,
#   - transport reactions can be removed - they are identified by reactants and products being the same.
#   - redundant reactions can be merge - same reactions in diff compartments become one.
#
# Minghao Gong, 2022-04-26

# %%
# !pip install cobra --user --ignore-installed ruamel.yaml
# !pip install --upgrade metDataModel # https://github.com/shuzhao-li/metDataModel/ 
# !pip install --upgrade numpy pandas

# %%
import cobra # https://cobrapy.readthedocs.io/en/latest/io.html#SBML
from metDataModel.core import Compound, Reaction, Pathway, MetabolicModel
import requests
import sys
import re

sys.path.append("/Users/gongm/Documents/projects/mass2chem/")
sys.path.append("/Users/gongm/Documents/projects/JMS/JMS/JMS")
from mass2chem.formula import *
from jms.formula import *
from jms.utils.gems import *
from jms.utils.git_download import *

# %%
# download the most updated Rat-GEM.xml
model_name = 'Clostridium_sporogenes-Carve'
file_name = 'Clostridium_sporogenes_carveme.xml'
local_path = output_fdr = f'../testdata/draftGenome-GEM-JMS/CarveMe/'

# %%
# Read the model via cobra
model = cobra.io.read_sbml_model(os.path.join(local_path,file_name))
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %%
model
# Out:
# <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>

# %%
# metabolite entries, readily convert to list of metabolites
model.metabolites[33]
# Out:
# <Metabolite nadh_c at 0x7fc463a6d700>

# %%
# CarveMe has some particularly strange 
[x.formula for x in model.metabolites]
# Out:
# ['C20H21N7O7',
#  'C10H12N5O10P2',
#  'C10H12N5O13P3',
#  'C5H8NO4',
#  'HPO4;HO4P',
#  'C27H52O5',
#  'C27H52O5',
#  'C31H60O5',
#  'C31H60O5',
#  'C31H56O5',
#  'C31H56O5',
#  'C35H68O5',
#  'C35H68O5',
#  'C35H64O5',
#  'C35H64O5',
#  'C39H76O5',
#  'C39H76O5',
#  'C39H72O5',
#  'C39H72O5',
#  'H2O',
#  'C3H6O',
#  'C3H8O2',
#  'C3H8O2',
#  'C6H12O6',
#  'C6H12O6',
#  'H2O',
#  'H2O2',
#  'H4N;NH4',
#  'O2',
#  'H',
#  'C9H11N2O12P2',
#  'C15H22N2O17P2',
#  'C21H26N7O14P2',
#  'C21H27N7O14P2',
#  'C21H32N7O16P3S',
#  'C21H25N7O17P3',
#  'C21H26N7O17P3',
#  'H',
#  'C5H9O4',
#  'C6H11O4',
#  'C6H9O6PS',
#  'H2O',
#  'C7H14N2O4',
#  'C7H5NO4',
#  'C19H36O7P1',
#  'C19H36O7P1',
#  'C17H36NO7P1',
#  'C17H36NO7P1',
#  'C19H40NO7P1',
#  'C19H40NO7P1',
#  'C19H38NO7P1',
#  'C19H38NO7P1',
#  'C21H44NO7P1',
#  'C21H44NO7P1',
#  'C21H42NO7P1',
#  'C21H42NO7P1',
#  'C23H48NO7P1',
#  'C23H48NO7P1',
#  'C23H46NO7P1',
#  'C23H46NO7P1',
#  'C10H12N5O7P',
#  'C12H23O2',
#  'C29H58N1O8P1',
#  'HO7P2;P2HO7',
#  'C33H66N1O8P1',
#  'C14H27O2',
#  'C33H62N1O8P1',
#  'C14H25O2',
#  'C16H31O2',
#  'C37H74N1O8P1',
#  'C16H29O2',
#  'C37H70N1O8P1',
#  'C18H35O2',
#  'C41H82N1O8P1',
#  'C18H33O2',
#  'C41H78N1O8P1',
#  'C18H36O9P1',
#  'C18H36O9P1',
#  'C20H40O9P1',
#  'C20H40O9P1',
#  'C20H38O9P1',
#  'C20H38O9P1',
#  'C22H44O9P1',
#  'C22H44O9P1',
#  'C22H42O9P1',
#  'C22H42O9P1',
#  'C24H48O9P1',
#  'C24H48O9P1',
#  'C24H46O9P1',
#  'C24H46O9P1',
#  'C30H58O10P1',
#  'C34H66O10P1',
#  'C34H62O10P1',
#  'C38H74O10P1',
#  'C38H70O10P1',
#  'C42H82O10P1',
#  'C42H78O10P1',
#  'C3H3O3',
#  'C10H11N5O10P2',
#  'C10H11N5O13P2S',
#  'C3H6NO5S',
#  'C5H4O5',
#  'C4H7NO3',
#  'C7H10O10P',
#  'C6H11O7',
#  'C6H11O7',
#  'C6H9O4',
#  'C5H7O3',
#  'CH2O',
#  'C5H9O7P',
#  'C5H10O4',
#  'C4H5O3',
#  'H',
#  'CHO3;HCO3',
#  'Na',
#  'Na',
#  'CHO3;HCO3',
#  'C7H8O2',
#  'C7H8O2',
#  'C6H10O6',
#  'C6H8N3O7P2',
#  'C6H8N3O4P',
#  'C26H38N7O17P3S',
#  'C3H4O7P',
#  'C2H2O6P',
#  'C2H2O6P',
#  'HPO4;HO4P',
#  'C10H12N5O11P2',
#  'C10H12N5O14P3',
#  'C3H5O3',
#  'CO2',
#  'C14H20N6O5S',
#  'C15H23N6O5S',
#  'C6H13NO2',
#  'C6H13NO2',
#  'C9H7O4',
#  'C394H621O144N96P1S3;C21H39N2O9PRS',
#  'HSR;HX;C384H603N96O142P1S3;C11H21N2O7PRS',
#  'C396H625O144N96P1S3;C23H43N2O9PRS',
#  'C23H41N2O9PRS;C396H623O144N96P1S3',
#  'C25H47N2O9PRS;C398H629O144N96P1S3',
#  'C398H627O144N96P1S3;C25H45N2O9PRS',
#  'C17H31N2O9PRS;C390H613O144N96P1S3',
#  'C392H617O144N96P1S3;C19H35N2O9PRS',
#  'C21H37N2O8PRS;C394H619O143N96P1S3',
#  'C23H41N2O8PRS;C396H623O143N96P1S3',
#  'C396H621O143N96P1S3;C23H39N2O8PRS',
#  'C398H627O143N96P1S3;C25H45N2O8PRS',
#  'C25H43N2O8PRS;C398H625O143N96P1S3',
#  'C400H633O144N96P1S3;C27H51N2O9PRS',
#  'C400H631O143N96P1S3;C27H49N2O8PRS',
#  'C400H631O144N96P1S3;C27H49N2O9PRS',
#  'C27H47N2O8PRS;C400H629O143N96P1S3',
#  'C402H637O144N96P1S3;C29H55N2O9PRS',
#  'C402H635O143N96P1S3;C29H53N2O8PRS',
#  'C29H53N2O9PRS;C402H635O144N96P1S3',
#  'C29H51N2O8PRS;C402H633O143N96P1S3',
#  'C388H609O144N96P1S3;C15H27N2O9PRS',
#  'C15H25N2O8PRS;C388H607O143N96P1S3',
#  'C17H29N2O8PRS;C390H611O143N96P1S3',
#  'C19H33N2O8PRS;C392H615O143N96P1S3',
#  'C8H15NOS2',
#  'C6H9O3',
#  'C5H9O2',
#  'Na',
#  'C5H9O2',
#  'H2O2',
#  'H4N;NH4',
#  'O2',
#  'C10H13N5O4',
#  'C9H12N2O6',
#  'C9H13N3O5',
#  'C10H13N5O5;C10H12N5O5',
#  'C39H66N7O18P3S',
#  'C39H64N7O18P3S',
#  'C24H34N7O19P3S;C24H33N7O19P3S',
#  'C37H62N7O17P3S',
#  'C27H37N7O20P3S',
#  'C4H4O4',
#  'C25H35N7O19P3S',
#  'C21H37N2O9PRS;C394H619O144N96P1S3',
#  'C23H41N2O9PRS;C396H623O144N96P1S3',
#  'C396H621O144N96P1S3;C23H39N2O9PRS',
#  'C398H627O144N96P1S3;C25H45N2O9PRS',
#  'C25H43N2O9PRS;C398H625O144N96P1S3',
#  'C400H631O144N96P1S3;C27H49N2O9PRS',
#  'C400H629O144N96P1S3;C27H47N2O9PRS',
#  'C29H53N2O9PRS;C402H635O144N96P1S3',
#  'C29H51N2O9PRS;C402H633O144N96P1S3',
#  'C15H25N2O9PRS;C388H607O144N96P1S3',
#  'C390H611O144N96P1S3;C17H29N2O9PRS',
#  'C19H33N2O9PRS;C392H615O144N96P1S3',
#  'C387H604O145N96P1S3;C14H22N2O10PRS',
#  'C19H35N2O8PRS;C392H617O143N96P1S3',
#  'C394H621O143N96P1S3;C21H39N2O8PRS',
#  'C21H37N2O8PRS;C394H619O143N96P1S3',
#  'C23H43N2O8PRS;C396H625O143N96P1S3',
#  'C23H41N2O8PRS;C396H623O143N96P1S3',
#  'C398H629O143N96P1S3;C25H47N2O8PRS',
#  'C398H627O143N96P1S3;C25H45N2O8PRS',
#  'C400H633O143N96P1S3;C27H51N2O8PRS',
#  'C400H631O143N96P1S3;C27H49N2O8PRS',
#  'C388H609O143N96P1S3;C15H27N2O8PRS',
#  'C17H31N2O8PRS;C390H613O143N96P1S3',
#  'C23H34N7O17P3S',
#  'C15H25N4O8',
#  'C15H25N4O8',
#  'C3H4O7P',
#  'H2',
#  'C29H38N7O17P3S',
#  'C4H6NO4',
#  'O3S;HSO3',
#  'C4H9NO2',
#  'C4H10NO',
#  'C7H6NO2',
#  'C4H5O3',
#  'C8H7O3',
#  'C7H6O2',
#  'C7H6O2',
#  'C7H6O2',
#  'C7H8O2',
#  'C7H8O2',
#  'C7H5O3',
#  'C28H40N7O17P3S',
#  'Fe8S8X',
#  'Fe8S8X',
#  'C7H5O3',
#  'C7H5O3',
#  'C27H31N9O15P2',
#  'C27H33N9O15P2',
#  'C8H7O3',
#  'C3H7NO2',
#  'C3H7NO2',
#  'C4H9NO4',
#  'C4H8NO7P',
#  'C6H6N2O3;C6H7N2O3',
#  'C6H9O3',
#  'C8H8O',
#  'C8H10O',
#  'C8H7O2',
#  'C7H7O4',
#  'C7H8O2',
#  'CHO2;CH1O2',
#  'C5H5O3',
#  'C6H7O3',
#  'Cl',
#  'Cl',
#  'C18H30N5O9',
#  'C3H7NO2',
#  'C18H30N5O9',
#  'C3H7NO2',
#  'C29H38N7O18P3S;C29H42N7O18P3S',
#  'C5H9NO3',
#  'C6H9O7',
#  'C6H9O7',
#  'C5H10O4',
#  'C5H5N5',
#  'C10H13N5O3',
#  'C5H8O14P3',
#  'C20H21N7O7',
#  'C17H19N4O6;C17H20N4O6',
#  'C8H13N3O7P;C8H12N3O7P',
#  'C11H15N5O3S',
#  'C20H23N7O6;C20H24N7O6',
#  'C6H12O4S',
#  'C2H4O',
#  'C9H12N5O13P3;C9H11N5O13P3',
#  'HO10P3',
#  'C6H11O9P',
#  'C13H19O10P;C13H17O10P',
#  'C5H10N2O3',
#  'C3H7NO2S',
#  'C3H7NO3',
#  'C4H9NO3',
#  'C15H22N2O17P2',
#  'C5H9O8P',
#  'C5H9O8P',
#  'C6H9N3O2',
#  'C2H3O2',
#  'C25H36N7O18P3S',
#  'C402H635O143N96P1S3;C29H53N2O8PRS',
#  'C402H637O143N96P1S3;C29H55N2O8PRS',
#  'C10H19O2',
#  'C8H15O2',
#  'C3H4O2',
#  'C10H13N2O11P2',
#  'C5H10O5',
#  'C12H15O10P',
#  'C6H6O2',
#  'C5H10O5',
#  'C5H10O5',
#  'C4H9NO2',
#  'C4H9NO2',
#  'C27H40N7O18P3S',
#  'C25H38N7O17P3S',
#  'C29H44N7O18P3S',
#  'C27H42N7O17P3S',
#  'C31H48N7O18P3S',
#  'C29H46N7O17P3S',
#  'C33H52N7O18P3S',
#  'C31H50N7O17P3S',
#  'C31H50N7O17P3S',
#  'C35H56N7O18P3S',
#  'C33H54N7O17P3S',
#  'C33H54N7O17P3S',
#  'C37H60N7O18P3S',
#  'C35H58N7O17P3S',
#  'C4H8O2',
#  'C2H4O',
#  'C3H5O2',
#  'C24H36N7O17P3S',
#  'C5H7O3S',
#  'CO',
#  'C6H11O9P',
#  'C10H11N4O11P2',
#  'C10H11N4O14P3',
#  'C3H2O6P',
#  'C8H15NO6',
#  'C8H15NO6',
#  'C8H15NO6',
#  'C8H14NO9P',
#  'C6H13NO8P',
#  'C8H14NO9P',
#  'C17H25N3O17P2',
#  'C55H89O4P',
#  'C9H11N2O9P',
#  'C8H15NO6',
#  'C7H9NO5',
#  'C6H9O4',
#  'C2H3O2',
#  'C5H14NO',
#  'C2H6O',
#  'C6H11NO4',
#  'C6H5O7',
#  'C4H2O5',
#  'C2H3O5P',
#  'C5H7O4',
#  'C12H16N4O7P2S',
#  'C11H17NO11P',
#  'C3H5O3',
#  'C8H14NO9P',
#  'C8H15NO6',
#  'C6H11O9P',
#  'C11H18NO9',
#  'C9H12N3O14P3',
#  'C25H36N7O17P3S',
#  'C27H40N7O17P3S',
#  'C26H40N7O17P3S',
#  'C29H44N7O17P3S',
#  'C31H48N7O17P3S',
#  'C33H52N7O17P3S',
#  'C33H52N7O17P3S',
#  'C35H56N7O17P3S',
#  'C37H60N7O17P3S',
#  'C39H64N7O17P3S',
#  'C39H66N7O17P3S',
#  'C25H38N7O17P3S',
#  'C386H605O143N96P1S3;C13H23N2O8PRS',
#  'C7H14N2O3',
#  'C5H13N2O2',
#  'C5H13N2O2',
#  'C6H3O6',
#  'C6H5O7',
#  'HPO4;HO4P',
#  'C17H19N4O6;C17H20N4O6',
#  'C17H18N4O9P;C17H19N4O9P',
#  'C12H24O5P1',
#  'C14H28O5P',
#  'C14H26O5P',
#  'C16H32O5P',
#  'C16H30O5P',
#  'C18H36O5P',
#  'C18H34O5P',
#  'C11H20N2O7PS;C11H21N2O7PS',
#  'C5H9NO4',
#  'HS2O3;O3S2',
#  'C3H6NO5S2',
#  'C2H3O2',
#  'C4H8O2',
#  'C3H4O10P2',
#  'C10H12N4O5',
#  'C9H12N3O7P',
#  'C9H13N3O4',
#  'H4N;NH4',
#  'C10H10NO5',
#  'C58H84CoN16O11',
#  'C10H8O6',
#  'C5H4N4O',
#  'C5H5N5',
#  'C10H12N5O9P2',
#  'C10H12N5O6P',
#  'C10H12N5O12P3',
#  'C14H24N6O3S',
#  'C10H12N5O10P2',
#  'C10H12N5O13P3',
#  'C5H10O5',
#  'C72H100CoN18O17P',
#  'C10H12N5O8P',
#  'C7H14N2O4',
#  'C6H11O9P',
#  'C6H11O9P',
#  'C5H9O8P',
#  'C9H13N4O8P',
#  'C7H15NO3',
#  'C10H12N5O10PS',
#  'C14H14N5O11P',
#  'C4H2O4',
#  'C13H15N4O12P',
#  'C10H11N4O8P',
#  'C37H60N7O17P3S',
#  'C39H64N7O17P3S',
#  'C9H12N3O8P',
#  'C19H29N2O12',
#  'C34H52N6O19',
#  'C19H29N2O12',
#  'C34H52N6O19',
#  'C26H39N5O14',
#  'C37H57N7O20',
#  'C37H57N7O20',
#  'C29H44N6O15',
#  'C5H16N4',
#  'C11H16NO7',
#  'C6H12O6',
#  'C4H14N2',
#  'C5H16N4',
#  'C4H14N2',
#  'CH4N2O;CH5N2O',
#  'C15H29O7P1',
#  'C27H51O8P1',
#  'C17H33O7P1',
#  'C31H59O8P1',
#  'C17H31O7P1',
#  'C31H55O8P1',
#  'C19H37O7P1;C19H37O7P',
#  'C35H67O8P1',
#  'C19H35O7P1',
#  'C35H63O8P1',
#  'C21H41O7P;C21H41O7P1',
#  'C39H75O8P1',
#  'C21H39O7P1;C21H39O7P',
#  'C39H71O8P1',
#  'C2HO3;C2H1O3',
#  'C2H5NO2',
#  'C6H11O9P',
#  'C4H9NO2S',
#  'C9H17NO6S',
#  'C6H9N3O',
#  'C2H4O2',
#  'C5H11NO2S',
#  'CH4S',
#  'HS;H2S',
#  'X;C6H7NO2S2R2',
#  'XH2;C6H9NO2S2R2',
#  'C10H13N4O9P',
#  'C19H21N7O6',
#  'C9H11N3O9P',
#  'C9H11N3O9P',
#  'C12H20NO4S2',
#  'C8H17NOS2',
#  'C4H4O5',
#  'C4H4O5',
#  'C9H13N5O4',
#  'C3H5O4',
#  'C3H7NO2',
#  'C6H12N2O3',
#  'C6H12N2O3',
#  'C6H12N2O3',
#  'C4H8N2O3',
#  'C3H7NO2',
#  'C3H7NO2',
#  'C5H10N2O3',
#  'C2H5NO2',
#  'C8H13N2O5',
#  'C3H7NO3',
#  'C5H8NO4',
#  'C8H12N2O5P',
#  'C8H8NO6P;C8H7NO6P',
#  'C4H9NO3',
#  'C6H15N4O2',
#  'C6H15N4O2',
#  'CH4O1;CH4O',
#  'C3H6O3',
#  'C3H8O3',
#  'C3H6O2',
#  'C8H8O',
#  'C10H9NO',
#  'C4H8O',
#  'C4H10O',
#  'C8H7O2',
#  'C10H8NO2',
#  'C2H6NO',
#  'C4H7O2',
#  'C3H6O3',
#  'C3H5O6P',
#  'C4H7N4O4',
#  'C3H5N2O4',
#  'C4H5N4O3;C4H6N4O3',
#  'C4H5N4O3;C4H6N4O3',
#  'C37H74N1O8P1',
#  'C38H74O10P1',
#  'C6H9O6',
#  'C12H22O11',
#  'C6H12O6',
#  'C50H72O2',
#  'C51H74O2',
#  'C50H70O2',
#  'C51H72O2',
#  'C5H10N2O3S',
#  'C5H10N2O3S',
#  'C5H9NO2',
#  'C7H12N2O3',
#  'C12H22O11',
#  'C19H29N2O12',
#  'C11H14N2O8P;C11H13N2O8P',
#  'C6H11N3O4P',
#  'C6H7N2O5P;C6H8N2O5P',
#  'C20H24N10O19P4',
#  'C7H7NO4',
#  'C12H20N2O9PS;C12H19N2O9PS',
#  'C5H16N2',
#  'C3H7O6P',
#  'C6H15N2O2',
#  'C21H33N7O13P2S',
#  'C9H15N4O9P',
#  'C9H13N4O9P',
#  'C5H10O5',
#  'C5H10O5',
#  'C5H10O5',
#  'Fe',
#  'Fe',
#  'C17H21N4O9P',
#  'C12H16O7',
#  'C6H15N4O2',
#  'CO2',
#  'C6H13N3O3;C6H14N3O3',
#  'C6H15N2O2',
#  'C5H13N2O2',
#  'C5H13N2O2',
#  'C10H17N4O6',
#  'C9H11NO2',
#  'O4S;SO4',
#  'C4H6NO7P',
#  'C4H7NO3',
#  'C4H6NO4',
#  'C4H6NO4',
#  'AsO3',
#  'AsO3',
#  'AsO3',
#  'AsO4',
#  'AsO4',
#  'AsO4',
#  'C5H7N2O5;C5H6N2O5',
#  'CH2NO5P',
#  'K',
#  'K',
#  'C4H3NO4',
#  'C49H74O4',
#  'C49H76O4',
#  'C5H9NO2',
#  'C20H30N6O12S2;C20H28N6O12S2',
#  'C10H15N3O6S;C10H16N3O6S',
#  'C4H9NO3',
#  'C15H19N5O20P4',
#  'C10H15N2O3S',
#  'C7H5O2',
#  'CHO3;HCO3',
#  'C6H13NO2',
#  'C16H23N5O16P2',
#  'C5H11NO2',
#  'C12H21O14P',
#  'C12H22O11',
#  'C12H22O11',
#  'C12H21O14P',
#  'CH4O1;CH4O',
#  'C7H14O6',
#  'C7H14O6',
#  'C15H19N2O18P2',
#  'C4H7O7P',
#  'Cu',
#  'C10H10N5O8PS2Mo',
#  'C20H22N10O12P2S2Cu',
#  'C32H39N7O20P3S',
#  'C4H10O2',
#  'C4H10O',
#  'C4H10O',
#  'C10H17N2O3',
#  'S',
#  'SFe2',
#  'S2Fe2',
#  'C4H7N2O3;C4H8N2O3',
#  'C4H7O5P',
#  'C4H7O2',
#  'C4H7O2',
#  'C7H6O',
#  'C7H6O',
#  'C7H6O',
#  'C6H6O2',
#  'C7H5O2',
#  'C31H50N7O18P3S',
#  'C33H54N7O18P3S',
#  'C35H58N7O18P3S',
#  'C26H40N7O17P3S',
#  'Ca',
#  'Ca',
#  'Ca',
#  'XH2;Fe8S8XH2;Fe2S2X',
#  'C5H16N2',
#  'C6H15N2O2',
#  'C6H6O4',
#  'C6H6O2',
#  'C6H6O2',
#  'C48H72CoN11O8',
#  'C62CoH88N13O14P;C62H88CoN13O14P',
#  'Cd',
#  'Cd',
#  'Cd',
#  'K',
#  'C36H63N3O15P2',
#  'C40H71N3O15P2',
#  'C40H67N3O15P2',
#  'C44H79N3O15P2',
#  'C44H75N3O15P2',
#  'C48H87N3O15P2',
#  'C48H83N3O15P2',
#  'XH',
#  'XH',
#  'C20H22N10O14P2',
#  'C20H23N10O15P2',
#  'C14H22N3O17P3',
#  'C14H23N3O14P2',
#  'C9H12N3O11P2',
#  'C3H3O3',
#  'C5H10N2O3S',
#  'C5H14NO',
#  'C5H13NO4S',
#  'C5H13NO4S',
#  'C10H8O6',
#  'C10H9O10P',
#  'C6H5O7',
#  'Mg',
#  'Mg',
#  'Mn',
#  'Mn',
#  'Ni',
#  'Ni',
#  'Co',
#  'Co',
#  'Zn',
#  'Zn',
#  'C4H4O4',
#  'C4H4O4',
#  'CHO2;CH1O2',
#  'C114H202N2O39P2',
#  'C114H202N2O39P2',
#  'C2O4',
#  'C2O4',
#  'C27H51O8P1',
#  'C30H58O10P1',
#  'C31H59O8P1',
#  'C34H66O10P1',
#  'C31H55O8P1',
#  'C34H62O10P1',
#  'C35H67O8P1',
#  'C35H63O8P1',
#  'C38H70O10P1',
#  'C39H75O8P1',
#  'C42H82O10P1',
#  'C39H71O8P1',
#  'C42H78O10P1',
#  'C3H8O3',
#  'Cl',
#  'Fe',
#  'C4H5N3O',
#  'CO2',
#  'Co',
#  'Fe8S8X',
#  'Fe8S8X',
#  'C19CoN4R21',
#  'C20H3CoN4R21',
#  'CO',
#  'C10H13N5O8P',
#  'C36H40N4O8',
#  'C34H38N4O4',
#  'C7H8O',
#  'C7H15NO3',
#  'C7H15NO3',
#  'C7H15NO2',
#  'C7H15NO3',
#  'C7H15NO3',
#  'C7H15NO2',
#  'C7H15NO2',
#  'CrO4',
#  'CrO4',
#  'CrO4',
#  'C4H4N2O2',
#  'C7H22N3',
#  'C35H56N7O17P3S',
#  'C9H11N2O15P3',
#  'Cu',
#  'Cu',
#  'Cu',
#  'Cu',
#  'CHN',
#  'O3S;HSO3',
#  'CNS',
#  'HS2O3;O3S2',
#  'CHN',
#  'C14H18O4',
#  'C14H20O4',
#  'C10H17N5O4R',
#  'R',
#  'C3H7NO2S',
#  'O2',
#  'C6H12N2O4S2;C7H14N2O4S',
#  'C5H8NO4',
#  'C9H13N3O5',
#  'C9H12N3O10P2',
#  'C9H12N3O13P3',
#  'C5H7N3O',
#  'C10H13N5O3',
#  'C10H12N4O4',
#  'C7H14N2O4',
#  'C5H10O5',
#  'C10H11N4O13P3',
#  'C4H7O6P',
#  'C11H12NO9P',
#  'C10H19O2',
#  'C10H19O2',
#  'C9H11N2O8P',
#  'C15H25O7P2',
#  'C5H9O7P2',
#  'C9H11N2O14P3',
#  'C9H12N2O5',
#  'C9H13N3O4',
#  'C12H23O2',
#  'C6H9O6',
#  'C6H8O9P',
#  'C3H5O6P',
#  'Fe2S2X',
#  'C6H12O6',
#  'C10H12N5O7P',
#  'C10H13N5O4',
#  'C8H9O4',
#  'C27H39N7O20P3S',
#  'C6H9O3',
#  'C19H19N7O6',
#  'C14H13N6O3',
#  'C11H7O4',
#  'C40H65O7P2',
#  'C7H9N5O2',
#  'C5H5N2O4',
#  'C5H3N2O4',
#  'C29H40N7O19P3S',
#  'C9H12N5O7P',
#  'C4H6N2O2',
#  'C9H14N5O8P',
#  'C9H14N5O8P',
#  'C20H21N7O6',
#  'C5H8O4',
#  'C5H8O4',
#  'C7H9O6',
#  'C7H7O5',
#  'C10H11N4O7P;C10H12N4O7P',
#  'C6H10O12P2',
#  'C3H5O3',
#  'C5H9O7P2',
#  'C10H17O7P2',
#  'C9H16N4O6',
#  'C5H9O8P2',
#  'C21H24N6O15P2',
#  'C9H11N2O11P2',
#  'C10H13N2O14P3',
#  'C6H10O10P2',
#  'C6H11O4',
#  'C5H9O7P',
#  'C5H10O4',
#  'C10H15N3O6S;C10H16N3O6S',
#  'C42H40N4O16;C42H41N4O16',
#  'C3H5NO3',
#  'C3H7NO3',
#  'C3H7NO3',
#  'C10H13N2O8P',
#  'C5H6N2O2',
#  'C5H11O7P',
#  'C5H9O7P',
#  'C4H6O8P',
#  'C55H89O7P2',
#  'C25H38N7O18P3S',
#  'C25H38N7O18P3S',
#  'C27H42N7O18P3S',
#  'C29H46N7O18P3S',
#  'C37H62N7O18P3S',
#  'C26H40N7O18P3S',
#  'C84H148N2O37P2',
#  'C96H170N2O38P2',
#  'C110H196N2O39P2',
#  'C100H176N2O38P2',
#  'C114H202N2O39P2',
#  'C112H202N3O42P3',
#  'C112H202N3O42P3',
#  'C30H27N3O15',
#  'C30H27FeN3O15',
#  'C42H47N3O25',
#  'C30H27N3O15',
#  'C6H9O7',
#  'C11H12N2O2',
#  'C5H11NO2',
#  'C9H11NO3',
#  'C2H8NO',
#  'C2H8NO',
#  'C2H6O',
#  'C2H6O',
#  'H2',
#  'C6H12O6',
#  'C14H27O2',
#  'C14H25O2',
#  'C16H31O2',
#  'C16H29O2',
#  'C18H35O2',
#  'C18H33O2',
#  'C4H7O2',
#  'C6H11O2',
#  'C8H15O2',
#  'C6H11O9P',
#  'C7H12O13P2',
#  'C34H32FeN4O4;C34FeH30N4O4;C34H30FeN4O4',
#  'C34H32N4O4',
#  'C22H36N7O17P3S;C22H32N7O17P3S',
#  'CHO2;CH1O2',
#  'CH3O3S',
#  'C2H7NO3S;C2H6NO3S',
#  'Fe',
#  'Fe',
#  'Fe',
#  'C30H27FeN3O15',
#  'C30H27N3O15',
#  'C30H27FeN3O15',
#  'S4Fe3',
#  'S4Fe4',
#  'N2O',
#  'NO',
#  'C12H21O14P',
#  'C6H9N2O4;C6H8N2O4',
#  'X',
#  'XH2',
#  'C7H9N5O8P2;C7H8N5O8P2',
#  'C20H20N7O6;C20H21N7O6',
#  'C23H31N7O19P3S',
#  'C6H12O6',
#  'C6H12O6',
#  'C20H22N8O6',
#  'C4H2O4',
#  'C4H2O4',
#  'C6H13NO8P',
#  'C6H12O6',
#  'C5H9NO3',
#  'C5H14NO6P',
#  'C5H14NO6P',
#  'C5H14NO6P',
#  'C6H14O8P',
#  'C6H14O8P',
#  'C6H14O8P',
#  'C5H6NO2',
#  'C5H9NO3',
#  'C6H11O9P',
#  'C6H11O7',
#  'C6H12O6',
#  'C6H12O6',
#  'C6H11O9P',
#  'C6H13O9P',
#  'C6H14O6',
#  'C6H9O7',
#  'C6H9O7',
#  'C6H14NO5',
#  'C8H12N2O9P;C8H13N2O9P',
#  'C7H14N2O8P;C7H13N2O8P',
#  'C2H3O3',
#  'CH6NS2X',
#  'S2X',
#  'H2S2X',
#  'C10H12N5O20P5;C10H11N5O20P5',
#  'C6H9O7',
#  'C17H20N2O8',
#  'C6H11O7',
#  'C3H3O4',
#  'C6H9O7',
#  'C6H9O7',
#  'C5H10N2O3',
#  'C95H152N8O28P2',
#  'C5H8NO4',
#  'C5H11NO7P',
#  'C5H7NO3R;C5H8NO4X',
#  'R;HOX;C15H21N5O10PR',
#  'C3H7O6P',
#  'C2H5NO2',
#  'C5H11NO2',
#  'C3H3O4',
#  'C3H8O3',
#  'C13H19N3O8S;C13H20N3O8S',
#  'C10H11N4O9P',
#  'C5H4N5O;C5H5N5O',
#  'C3H7NO3',
#  'C6H12O6',
#  'X',
#  'XH2',
#  'C17H36N6O5S',
#  'H2O2',
#  'C10H11N4O15P3',
#  'C5H4N4O2',
#  'C5H4N5O;C5H5N5O',
#  'C5H4N5O;C5H5N5O',
#  'HS;H2S',
#  'H2',
#  'C26H38N7O18P3S',
#  'H3NO',
#  'C47H69O3',
#  'C6H13N3O;C6H12N3O',
#  'XH2',
#  'X',
#  'C34H32FeN4O4;C34FeH30N4O4;C34H30FeN4O4',
#  'C6H9NOS',
#  'C6H8NO4PS',
#  'Hg',
#  'Hg',
#  'Hg',
#  'C6H9N3O2',
#  'C6H9N3O2',
#  'C6H5N2O2',
#  'C40H38N4O17',
#  'C10H13N2O4',
#  'C27H40N7O20P3S;C27H39N7O20P3S',
#  'C6H11O4',
#  'C4H9NO3',
#  'C5H7O4',
#  'C6H9O4',
#  'C8H7O3',
#  'C6H6O2',
#  'C4H8NO6P',
#  'C8H12NO6',
#  'C5H4N4O',
#  'C5H4N4O',
#  'C6H11O2',
#  'C8H13N2O2',
#  'C2H7NO3S;C2H6NO3S',
#  'HSR',
#  'HS2R',
#  'H8O2S6R',
#  'H4O2S8Fe2R',
#  'O2S10Fe4R',
#  'H4O2S10Fe4R',
#  'C4H7O2',
#  'C6H5O7',
#  'C10H9NO',
#  'C6H11O7',
#  'C6H11O7',
#  'C6H9N2O6P',
#  'C15H22N5O15P2;C15H21N5O15P2',
#  'C6H13NO2',
#  'C6H13NO2',
#  'C11H8NO3',
#  'C6H12O6',
#  'C31H39N8O17P3S',
#  'C9H7O3',
#  'C84H148N2O37P2',
#  'C84H148N2O37P2',
#  'C17H24N3O15P',
#  'C8H13O8',
#  'C8H12O11P',
#  'C12H22O11',
#  'C12H22O11',
#  'C12H22O11',
#  'C8H13N2O5',
#  'C8H13N2O5',
#  'C3H6NO5S',
#  'C3H6NO5S',
#  'C6H13NO2',
#  'C110H196N2O39P2',
#  'C110H196N2O39P2',
#  'C8H13OS2',
#  'C8H15O',
#  'C68H127N2O20P',
#  'C34H64NO12P',
#  'C43H75N3O20P2',
#  'C17H36NO7P1',
#  'C19H40NO7P1',
#  'C23H46NO7P1',
#  'C18H36O9P1',
#  'C20H40O9P1',
#  'C22H44O9P1',
#  'C24H48O9P1',
#  'C24H46O9P1',
#  'C6H13O9P',
#  'C12H21O14P',
#  'C4H4O5',
#  'C12H22O11',
#  'C12H22O11',
#  'C18H32O16',
#  'C6H12O6',
#  'C12H22O11',
#  'C18H32O16',
#  ...]

# %%
model.metabolites[33].__dict__
# Out:
# {'_id': 'nadh_c',
#  'name': 'Nicotinamide adenine dinucleotide - reduced',
#  'notes': {'FORMULA': 'C21H27N7O14P2',
#   'BioCyc': 'META:NADH',
#   'SEED Compound': 'cpd00004',
#   'UniPathway Compound': 'UPC00004',
#   'KEGG Compound': 'C00004',
#   'BioPath Molecule': 'NADH',
#   'MetaNetX (MNX) Chemical': 'MNXM10',
#   'Reactome': '192305;194697;29362;73473',
#   'Human Metabolome Database': 'HMDB01487'},
#  '_annotation': {},
#  '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#  '_reaction': {<Reaction 4MBZALDH at 0x7fc449961b50>,
#   <Reaction 4MBZDH at 0x7fc44993c790>,
#   <Reaction ABUTD at 0x7fc4499838e0>,
#   <Reaction ACALD at 0x7fc4499830d0>,
#   <Reaction ACOAD1 at 0x7fc44999dee0>,
#   <Reaction ACOAD2 at 0x7fc4499a7ee0>,
#   <Reaction ACOAD4_1 at 0x7fc4499a7f70>,
#   <Reaction ACOAD5_1 at 0x7fc44997b040>,
#   <Reaction ACTD2 at 0x7fc4499ccf70>,
#   <Reaction AKGDH at 0x7fc449a12850>,
#   <Reaction ALAD_L at 0x7fc449a12df0>,
#   <Reaction ALCD19 at 0x7fc449a2eb80>,
#   <Reaction ALCD1 at 0x7fc4499f8d60>,
#   <Reaction ALCD2x at 0x7fc449a2e850>,
#   <Reaction ALCD4 at 0x7fc449a23d00>,
#   <Reaction ALDD19xr at 0x7fc449a2ee50>,
#   <Reaction ALDD20x at 0x7fc449a37a60>,
#   <Reaction ALDD2x at 0x7fc449a2edc0>,
#   <Reaction ALDD31 at 0x7fc449a2ed60>,
#   <Reaction AMPMS2 at 0x7fc449a51d90>,
#   <Reaction BTDD_RR at 0x7fc449aa7f70>,
#   <Reaction BZDH at 0x7fc449ab9e80>,
#   <Reaction DH4MCHCDH at 0x7fc449b91ca0>,
#   <Reaction DMPPS at 0x7fc449bb96a0>,
#   <Reaction DURADx at 0x7fc449bcef40>,
#   <Reaction E4PD at 0x7fc449bcef10>,
#   <Reaction EAR100x at 0x7fc449bcefa0>,
#   <Reaction EAR120x at 0x7fc449be2f70>,
#   <Reaction EAR121x at 0x7fc449be2e20>,
#   <Reaction EAR140x at 0x7fc449be2c10>,
#   <Reaction EAR141x at 0x7fc449be2cd0>,
#   <Reaction EAR160x at 0x7fc449be2580>,
#   <Reaction EAR161x at 0x7fc449be25e0>,
#   <Reaction EAR180x at 0x7fc449be2730>,
#   <Reaction EAR181x at 0x7fc449bcee20>,
#   <Reaction EAR40x at 0x7fc449be2d90>,
#   <Reaction EAR60x at 0x7fc449be2a00>,
#   <Reaction EAR80x at 0x7fc449be2e50>,
#   <Reaction FAO3 at 0x7fc449c34c10>,
#   <Reaction FLNDPR2r at 0x7fc449c6eeb0>,
#   <Reaction FMNRx at 0x7fc449c6e9d0>,
#   <Reaction FRNDPR2r_1 at 0x7fc449c74a30>,
#   <Reaction G3PD1 at 0x7fc449c94c40>,
#   <Reaction GAPD at 0x7fc449ca7940>,
#   <Reaction GCALDD at 0x7fc449cbdf70>,
#   <Reaction GCCc at 0x7fc449cbdc70>,
#   <Reaction GLTPD at 0x7fc449cd1820>,
#   <Reaction GLUDxi at 0x7fc449cf6fa0>,
#   <Reaction GLYALDDr at 0x7fc449d07ca0>,
#   <Reaction GLYCDx at 0x7fc449d07a90>,
#   <Reaction GLYCL at 0x7fc449d07e80>,
#   <Reaction HACD1 at 0x7fc449d57be0>,
#   <Reaction HACD1_2 at 0x7fc449d57dc0>,
#   <Reaction HACD1i at 0x7fc449d43b20>,
#   <Reaction HACD2 at 0x7fc449d57e80>,
#   <Reaction HACD2i at 0x7fc449d43fa0>,
#   <Reaction HACD3 at 0x7fc449d57670>,
#   <Reaction HACD3i at 0x7fc449d57d90>,
#   <Reaction HACD4 at 0x7fc449d57af0>,
#   <Reaction HACD4i at 0x7fc449d43dc0>,
#   <Reaction HACD5 at 0x7fc449d57bb0>,
#   <Reaction HACD5i at 0x7fc449d57940>,
#   <Reaction HACD6 at 0x7fc449d43f70>,
#   <Reaction HACD6i at 0x7fc449d57ac0>,
#   <Reaction HACD7 at 0x7fc449d69d60>,
#   <Reaction HACD7i at 0x7fc449d69970>,
#   <Reaction HACD8 at 0x7fc449d69b20>,
#   <Reaction HACD8i at 0x7fc449d69eb0>,
#   <Reaction HACD9 at 0x7fc449d69ca0>,
#   <Reaction HADPCOADH3 at 0x7fc449d43cd0>,
#   <Reaction HAMR at 0x7fc449d57d00>,
#   <Reaction HISTD at 0x7fc449d7eb80>,
#   <Reaction HXAND at 0x7fc449dab7c0>,
#   <Reaction HYDFDN at 0x7fc449dabb20>,
#   <Reaction ICDHx at 0x7fc449dbe7c0>,
#   <Reaction ILEDHr at 0x7fc449cf6040>,
#   <Reaction IMPD at 0x7fc45d380580>,
#   <Reaction INS2D at 0x7fc449ce3c70>,
#   <Reaction IPDPS at 0x7fc449dd2fa0>,
#   <Reaction LCARS at 0x7fc449e334c0>,
#   <Reaction LDH_D at 0x7fc449e33d00>,
#   <Reaction LDH_L at 0x7fc449e33af0>,
#   <Reaction LIPOS at 0x7fc449e48eb0>,
#   <Reaction LPD5 at 0x7fc449e48f40>,
#   <Reaction M1PD at 0x7fc449e82460>,
#   <Reaction MDH at 0x7fc449ea77c0>,
#   <Reaction ME1 at 0x7fc449ea7e20>,
#   <Reaction MECDPDH2 at 0x7fc449ea7940>,
#   <Reaction MMSAD2 at 0x7fc449ee0df0>,
#   <Reaction MOADSUx at 0x7fc449ef36a0>,
#   <Reaction MTHFR2 at 0x7fc449f12d30>,
#   <Reaction MTHFR2_1 at 0x7fc449f12eb0>,
#   <Reaction N2OR at 0x7fc449f12fa0>,
#   <Reaction NADFADOR at 0x7fc449f2c9d0>,
#   <Reaction NADH10 at 0x7fc449f2c940>,
#   <Reaction NADH5 at 0x7fc449f2cee0>,
#   <Reaction NADH6 at 0x7fc449f2cf70>,
#   <Reaction NADH7 at 0x7fc449f12970>,
#   <Reaction NADH8 at 0x7fc449f2ca60>,
#   <Reaction NADH9 at 0x7fc449f2cf40>,
#   <Reaction NADHDH at 0x7fc449f12cd0>,
#   <Reaction NADHNQR at 0x7fc449f2cb50>,
#   <Reaction NHFRBO at 0x7fc449f51f70>,
#   <Reaction NOX at 0x7fc449f65b50>,
#   <Reaction OBDHc at 0x7fc449f8eca0>,
#   <Reaction OIVD1r at 0x7fc449fb8a90>,
#   <Reaction OIVD2 at 0x7fc449fb8be0>,
#   <Reaction OIVD3 at 0x7fc449fb89d0>,
#   <Reaction P5CRx at 0x7fc449fccca0>,
#   <Reaction PDH at 0x7fc449fdfe80>,
#   <Reaction PDHcr at 0x7fc44a007af0>,
#   <Reaction PDX5PO2 at 0x7fc449fdfaf0>,
#   <Reaction PDX5PS at 0x7fc449fccf10>,
#   <Reaction PERD at 0x7fc4498d0970>,
#   <Reaction PGCD at 0x7fc4498d07f0>,
#   <Reaction PPND at 0x7fc449a1c5e0>,
#   <Reaction PTOLDOX at 0x7fc44a0e7ac0>,
#   <Reaction PXMO at 0x7fc44a10ca60>,
#   <Reaction RDXR at 0x7fc44a130e20>,
#   <Reaction RNF at 0x7fc44a14bf10>,
#   <Reaction SBTD_D2 at 0x7fc44a179fd0>,
#   <Reaction SBTPD at 0x7fc44a18c970>,
#   <Reaction SHCHD2 at 0x7fc44a18cac0>,
#   <Reaction SSALx at 0x7fc44a1b5b20>,
#   <Reaction THRD at 0x7fc44a1ebca0>,
#   <Reaction UDPGD at 0x7fc44a23aca0>,
#   <Reaction VNDH_2 at 0x7fc44a263f40>,
#   <Reaction XAND at 0x7fc44a277d30>},
#  'formula': 'C21H27N7O14P2',
#  'compartment': 'C_c',
#  'charge': 0,
#  '_bound': 0.0}

# %%
# reaction entries, Readily convert to list of reactions
model.reactions[33]
# Out:
# <Reaction 2AGPGAT160 at 0x7fc4498fceb0>

# %%
model.reactions[33].__dict__
# Out:
# {'_id': '2AGPGAT160',
#  'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C16:0)',
#  'notes': {'MetaNetX (MNX) Equation': 'MNXR68143'},
#  '_annotation': {},
#  '_gene_reaction_rule': 'EDU36256_1',
#  'subsystem': '',
#  '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#  '_metabolites': {<Metabolite 2agpg160_c at 0x7fc463a6dfd0>: -1.0,
#   <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#   <Metabolite hdca_c at 0x7fc463a6dd60>: -1.0,
#   <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#   <Metabolite pg160_c at 0x7fc463adc310>: 1.0,
#   <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#  '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#  '_lower_bound': 0.0,
#  '_upper_bound': 1000.0}

# %%
# NO group or pathway information
# model.groups[33]

# %%
model.metabolites[33].__dict__
# Out:
# {'_id': 'nadh_c',
#  'name': 'Nicotinamide adenine dinucleotide - reduced',
#  'notes': {'FORMULA': 'C21H27N7O14P2',
#   'BioCyc': 'META:NADH',
#   'SEED Compound': 'cpd00004',
#   'UniPathway Compound': 'UPC00004',
#   'KEGG Compound': 'C00004',
#   'BioPath Molecule': 'NADH',
#   'MetaNetX (MNX) Chemical': 'MNXM10',
#   'Reactome': '192305;194697;29362;73473',
#   'Human Metabolome Database': 'HMDB01487'},
#  '_annotation': {},
#  '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#  '_reaction': {<Reaction 4MBZALDH at 0x7fc449961b50>,
#   <Reaction 4MBZDH at 0x7fc44993c790>,
#   <Reaction ABUTD at 0x7fc4499838e0>,
#   <Reaction ACALD at 0x7fc4499830d0>,
#   <Reaction ACOAD1 at 0x7fc44999dee0>,
#   <Reaction ACOAD2 at 0x7fc4499a7ee0>,
#   <Reaction ACOAD4_1 at 0x7fc4499a7f70>,
#   <Reaction ACOAD5_1 at 0x7fc44997b040>,
#   <Reaction ACTD2 at 0x7fc4499ccf70>,
#   <Reaction AKGDH at 0x7fc449a12850>,
#   <Reaction ALAD_L at 0x7fc449a12df0>,
#   <Reaction ALCD19 at 0x7fc449a2eb80>,
#   <Reaction ALCD1 at 0x7fc4499f8d60>,
#   <Reaction ALCD2x at 0x7fc449a2e850>,
#   <Reaction ALCD4 at 0x7fc449a23d00>,
#   <Reaction ALDD19xr at 0x7fc449a2ee50>,
#   <Reaction ALDD20x at 0x7fc449a37a60>,
#   <Reaction ALDD2x at 0x7fc449a2edc0>,
#   <Reaction ALDD31 at 0x7fc449a2ed60>,
#   <Reaction AMPMS2 at 0x7fc449a51d90>,
#   <Reaction BTDD_RR at 0x7fc449aa7f70>,
#   <Reaction BZDH at 0x7fc449ab9e80>,
#   <Reaction DH4MCHCDH at 0x7fc449b91ca0>,
#   <Reaction DMPPS at 0x7fc449bb96a0>,
#   <Reaction DURADx at 0x7fc449bcef40>,
#   <Reaction E4PD at 0x7fc449bcef10>,
#   <Reaction EAR100x at 0x7fc449bcefa0>,
#   <Reaction EAR120x at 0x7fc449be2f70>,
#   <Reaction EAR121x at 0x7fc449be2e20>,
#   <Reaction EAR140x at 0x7fc449be2c10>,
#   <Reaction EAR141x at 0x7fc449be2cd0>,
#   <Reaction EAR160x at 0x7fc449be2580>,
#   <Reaction EAR161x at 0x7fc449be25e0>,
#   <Reaction EAR180x at 0x7fc449be2730>,
#   <Reaction EAR181x at 0x7fc449bcee20>,
#   <Reaction EAR40x at 0x7fc449be2d90>,
#   <Reaction EAR60x at 0x7fc449be2a00>,
#   <Reaction EAR80x at 0x7fc449be2e50>,
#   <Reaction FAO3 at 0x7fc449c34c10>,
#   <Reaction FLNDPR2r at 0x7fc449c6eeb0>,
#   <Reaction FMNRx at 0x7fc449c6e9d0>,
#   <Reaction FRNDPR2r_1 at 0x7fc449c74a30>,
#   <Reaction G3PD1 at 0x7fc449c94c40>,
#   <Reaction GAPD at 0x7fc449ca7940>,
#   <Reaction GCALDD at 0x7fc449cbdf70>,
#   <Reaction GCCc at 0x7fc449cbdc70>,
#   <Reaction GLTPD at 0x7fc449cd1820>,
#   <Reaction GLUDxi at 0x7fc449cf6fa0>,
#   <Reaction GLYALDDr at 0x7fc449d07ca0>,
#   <Reaction GLYCDx at 0x7fc449d07a90>,
#   <Reaction GLYCL at 0x7fc449d07e80>,
#   <Reaction HACD1 at 0x7fc449d57be0>,
#   <Reaction HACD1_2 at 0x7fc449d57dc0>,
#   <Reaction HACD1i at 0x7fc449d43b20>,
#   <Reaction HACD2 at 0x7fc449d57e80>,
#   <Reaction HACD2i at 0x7fc449d43fa0>,
#   <Reaction HACD3 at 0x7fc449d57670>,
#   <Reaction HACD3i at 0x7fc449d57d90>,
#   <Reaction HACD4 at 0x7fc449d57af0>,
#   <Reaction HACD4i at 0x7fc449d43dc0>,
#   <Reaction HACD5 at 0x7fc449d57bb0>,
#   <Reaction HACD5i at 0x7fc449d57940>,
#   <Reaction HACD6 at 0x7fc449d43f70>,
#   <Reaction HACD6i at 0x7fc449d57ac0>,
#   <Reaction HACD7 at 0x7fc449d69d60>,
#   <Reaction HACD7i at 0x7fc449d69970>,
#   <Reaction HACD8 at 0x7fc449d69b20>,
#   <Reaction HACD8i at 0x7fc449d69eb0>,
#   <Reaction HACD9 at 0x7fc449d69ca0>,
#   <Reaction HADPCOADH3 at 0x7fc449d43cd0>,
#   <Reaction HAMR at 0x7fc449d57d00>,
#   <Reaction HISTD at 0x7fc449d7eb80>,
#   <Reaction HXAND at 0x7fc449dab7c0>,
#   <Reaction HYDFDN at 0x7fc449dabb20>,
#   <Reaction ICDHx at 0x7fc449dbe7c0>,
#   <Reaction ILEDHr at 0x7fc449cf6040>,
#   <Reaction IMPD at 0x7fc45d380580>,
#   <Reaction INS2D at 0x7fc449ce3c70>,
#   <Reaction IPDPS at 0x7fc449dd2fa0>,
#   <Reaction LCARS at 0x7fc449e334c0>,
#   <Reaction LDH_D at 0x7fc449e33d00>,
#   <Reaction LDH_L at 0x7fc449e33af0>,
#   <Reaction LIPOS at 0x7fc449e48eb0>,
#   <Reaction LPD5 at 0x7fc449e48f40>,
#   <Reaction M1PD at 0x7fc449e82460>,
#   <Reaction MDH at 0x7fc449ea77c0>,
#   <Reaction ME1 at 0x7fc449ea7e20>,
#   <Reaction MECDPDH2 at 0x7fc449ea7940>,
#   <Reaction MMSAD2 at 0x7fc449ee0df0>,
#   <Reaction MOADSUx at 0x7fc449ef36a0>,
#   <Reaction MTHFR2 at 0x7fc449f12d30>,
#   <Reaction MTHFR2_1 at 0x7fc449f12eb0>,
#   <Reaction N2OR at 0x7fc449f12fa0>,
#   <Reaction NADFADOR at 0x7fc449f2c9d0>,
#   <Reaction NADH10 at 0x7fc449f2c940>,
#   <Reaction NADH5 at 0x7fc449f2cee0>,
#   <Reaction NADH6 at 0x7fc449f2cf70>,
#   <Reaction NADH7 at 0x7fc449f12970>,
#   <Reaction NADH8 at 0x7fc449f2ca60>,
#   <Reaction NADH9 at 0x7fc449f2cf40>,
#   <Reaction NADHDH at 0x7fc449f12cd0>,
#   <Reaction NADHNQR at 0x7fc449f2cb50>,
#   <Reaction NHFRBO at 0x7fc449f51f70>,
#   <Reaction NOX at 0x7fc449f65b50>,
#   <Reaction OBDHc at 0x7fc449f8eca0>,
#   <Reaction OIVD1r at 0x7fc449fb8a90>,
#   <Reaction OIVD2 at 0x7fc449fb8be0>,
#   <Reaction OIVD3 at 0x7fc449fb89d0>,
#   <Reaction P5CRx at 0x7fc449fccca0>,
#   <Reaction PDH at 0x7fc449fdfe80>,
#   <Reaction PDHcr at 0x7fc44a007af0>,
#   <Reaction PDX5PO2 at 0x7fc449fdfaf0>,
#   <Reaction PDX5PS at 0x7fc449fccf10>,
#   <Reaction PERD at 0x7fc4498d0970>,
#   <Reaction PGCD at 0x7fc4498d07f0>,
#   <Reaction PPND at 0x7fc449a1c5e0>,
#   <Reaction PTOLDOX at 0x7fc44a0e7ac0>,
#   <Reaction PXMO at 0x7fc44a10ca60>,
#   <Reaction RDXR at 0x7fc44a130e20>,
#   <Reaction RNF at 0x7fc44a14bf10>,
#   <Reaction SBTD_D2 at 0x7fc44a179fd0>,
#   <Reaction SBTPD at 0x7fc44a18c970>,
#   <Reaction SHCHD2 at 0x7fc44a18cac0>,
#   <Reaction SSALx at 0x7fc44a1b5b20>,
#   <Reaction THRD at 0x7fc44a1ebca0>,
#   <Reaction UDPGD at 0x7fc44a23aca0>,
#   <Reaction VNDH_2 at 0x7fc44a263f40>,
#   <Reaction XAND at 0x7fc44a277d30>},
#  'formula': 'C21H27N7O14P2',
#  'compartment': 'C_c',
#  'charge': 0,
#  '_bound': 0.0}

# %% [markdown]
# ## Port metabolite

# %%
def port_metabolite(M):
    # convert cobra Metabolite to metDataModel Compound
    Cpd = Compound()
    Cpd.src_id = remove_compartment_by_split(M.id,'_')
    Cpd.id = remove_compartment_by_split(M.id,'_')              # temporarily the same with the source id
    Cpd.name = M.name
    Cpd.charged_formula = M.formula
    Cpd.db_ids = [[model_name,Cpd.src_id]] # using src_id to also reference Rat-GEM ID in db_ids field
    for k,v in M.notes.items():
        if isinstance(v,list):
            Cpd.db_ids.append([[k,x] for x in v])
        else: 
            if ":" in v:
                Cpd.db_ids.append([k,v.split(":")[1]])
            else:
                Cpd.db_ids.append([k,v])
    
    inchi_list = [x[1].split('=')[1] for x in Cpd.db_ids if x[0] == 'inchi']
    if len(inchi_list) ==1:
        Cpd.inchi = inchi_list[0]
    elif len(inchi_list) >1:
        Cpd.inchi = inchi_list
        
    return Cpd

# %%
myCpds = []
for i in range(len(model.metabolites)):
    myCpds.append(port_metabolite(model.metabolites[i]))

# %%
len(myCpds)
# Out:
# 1219

# %%
# remove duplicated compounds
myCpds = remove_duplicate_cpd(myCpds)

# %%
len(myCpds)
# Out:
# 854

# %%
def fetch_CarveMe_GEM_charge_formula(compound_list,Bigg_json_path,overwrite = True):
    with open(Bigg_json_path,'r') as f:
        list_Bigg_cpd = json.load(f)
    Bigg_dict = {}
    for Bigg_cpd in list_Bigg_cpd:
        Bigg_dict.update({Bigg_cpd['id']:Bigg_cpd})
    new_cpd_list = []
    for myCpd in compound_list:
        for k,v in Bigg_dict.items():
            if myCpd.id == k:
                if overwrite == True:
                    myCpd.charge = v['charge']
                    myCpd.charged_formula = v['charged_formula'] # the Bigg json is using `identifiers` rather than `db_ids`
                break
        new_cpd_list.append(myCpd)
    return new_cpd_list

# %%
with open('../jms/data/staged/Bigg_FM_CG_updated0427.json','r') as f:
    list_Bigg_cpd = json.load(f)
Bigg_dict = {}
for Bigg_cpd in list_Bigg_cpd:
    Bigg_dict.update({Bigg_cpd['id']:Bigg_cpd})

# %%
Bigg_dict['idon__L']
# Out:
# {'id': 'idon__L',
#  'name': 'L-Idonate',
#  'identifiers': [['BIGG', 'idon_DASH_L_p'],
#   ['BIGG', 'idon_L_p'],
#   ['BIGG', 'idon__L'],
#   ['BIGG', 'idon__L_p'],
#   ['KEGG', 'C00770'],
#   ['CHEBI', '13126'],
#   ['CHEBI', '17796'],
#   ['CHEBI', '21335'],
#   ['CHEBI', '21336'],
#   ['CHEBI', '57659'],
#   ['CHEBI', '58494'],
#   ['CHEBI', '6250'],
#   ['BioCyc', 'L-IDONATE'],
#   ['MetaNetX', 'MNXM1565'],
#   ['inchikey', 'RGHNJXZEOKUKBD-SKNVOMKLSA-M'],
#   ['SEED', 'cpd00573']],
#  'neutral_formula': '',
#  'charge': -1,
#  'charged_formula': 'C6H11O7',
#  'neutral_mono_mass': 0.0,
#  'SMILES': '',
#  'inchi': ''}

# %%
myCpds = fetch_CarveMe_GEM_charge_formula(myCpds,'../jms/data/staged/Bigg_FM_CG_updated0427.json')

# %%
myCpds[20].__dict__
# Out:
# {'internal_id': '',
#  'id': 'udp',
#  'name': 'UDP',
#  'db_ids': [['Clostridium_sporogenes-Carve', 'udp'],
#   ['FORMULA', 'C9H11N2O12P2'],
#   ['BioCyc', 'UDP;META'],
#   ['SEED Compound', 'cpd00014'],
#   ['UniPathway Compound', 'UPC00015'],
#   ['KEGG Compound', 'C00015;G10619'],
#   ['BioPath Molecule', 'Uridine-5-prime-diphosphate'],
#   ['MetaNetX (MNX) Chemical', 'MNXM17'],
#   ['Reactome', '110096;111814;158602;205687'],
#   ['Human Metabolome Database', 'HMDB00295']],
#  'neutral_formula': '',
#  'neutral_mono_mass': 0.0,
#  'charge': -3,
#  'charged_formula': 'C9H11N2O12P2',
#  'SMILES': '',
#  'inchi': '',
#  'src_id': 'udp'}

# %%
import warnings
def update_neutral_formula_mass(compound_list):
    for myCpd in compound_list:
        try:
            myCpd.neutral_formula = adjust_charge_in_formula(myCpd.charged_formula,myCpd.charge) 
            myCpd.neutral_mono_mass = neutral_formula2mass(myCpd.neutral_formula)
        except:
            warnings.warn(f'{myCpd.id} do not have legal charge or charge formula to convert')

# %%
update_neutral_formula_mass(myCpds)

# %%
# check those that doesn't have the charge and charged formula
[x.__dict__ for x in myCpds if x.id == 'idon__L']
# Out:
# [{'internal_id': '',
#   'id': 'idon__L',
#   'name': 'L-Idonate',
#   'db_ids': [['Clostridium_sporogenes-Carve', 'idon__L'],
#    ['FORMULA', 'C6H11O7'],
#    ['BioCyc', 'L-IDONATE'],
#    ['SEED Compound', 'cpd00573'],
#    ['UniPathway Compound', 'UPC00770'],
#    ['KEGG Compound', 'C00770'],
#    ['MetaNetX (MNX) Chemical', 'MNXM1565']],
#   'neutral_formula': 'C6H12O7',
#   'neutral_mono_mass': 196.058302,
#   'charge': -1,
#   'charged_formula': 'C6H11O7',
#   'SMILES': '',
#   'inchi': '',
#   'src_id': 'idon__L'}]

# %% [markdown]
# ## Port reactions

# %%
[x.__dict__ for x in model.reactions]
# Out:
# [{'_id': '12DGR120tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C12:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR7'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr120_p at 0x7fc463a6d1c0>: -1.0,
#    <Metabolite 12dgr120_c at 0x7fc463a6d220>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12DGR140tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C14:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81306'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr140_p at 0x7fc463a6d130>: -1.0,
#    <Metabolite 12dgr140_c at 0x7fc463a6d1f0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12DGR141tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C14:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR9'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr141_p at 0x7fc463a6d280>: -1.0,
#    <Metabolite 12dgr141_c at 0x7fc463a6d0d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12DGR160tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C16:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR10'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr160_p at 0x7fc463a6d2e0>: -1.0,
#    <Metabolite 12dgr160_c at 0x7fc463a6d2b0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12DGR161tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C16:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR11'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr161_p at 0x7fc463a6d340>: -1.0,
#    <Metabolite 12dgr161_c at 0x7fc463a6d310>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12DGR180tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C18:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR12'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr180_p at 0x7fc463a6d3a0>: -1.0,
#    <Metabolite 12dgr180_c at 0x7fc463a6d370>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12DGR181tipp',
#   'name': '1,2 diacylglycerol transport via flipping (periplasm to cytoplasm, n-C18:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR13'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12dgr181_p at 0x7fc463a6d400>: -1.0,
#    <Metabolite 12dgr181_c at 0x7fc463a6d3d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '12PPDt',
#   'name': 'S-Propane-1,2-diol facilitated transport',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR15'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 12ppd__S_e at 0x7fc463a6d490>: -1.0,
#    <Metabolite 12ppd__S_c at 0x7fc463a6d4c0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPA161tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphatidate (n-C16:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR52'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2hdec9eg3p_p at 0x7fc463a6d7c0>: -1.0,
#    <Metabolite 2hdec9eg3p_c at 0x7fc463a6d760>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE120tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C12:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68130'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe120_p at 0x7fc463a6d940>: -1.0,
#    <Metabolite 2agpe120_c at 0x7fc463a6d910>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE140tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68131'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe140_p at 0x7fc463a6d9a0>: -1.0,
#    <Metabolite 2agpe140_c at 0x7fc463a6d970>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE141tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C14:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR57'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe141_p at 0x7fc463a6da00>: -1.0,
#    <Metabolite 2agpe141_c at 0x7fc463a6d9d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE160tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68132'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe160_p at 0x7fc463a6da60>: -1.0,
#    <Metabolite 2agpe160_c at 0x7fc463a6da30>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE161tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C16:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR59'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe161_p at 0x7fc463a6d5b0>: -1.0,
#    <Metabolite 2agpe161_c at 0x7fc463a6da90>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE180tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68133'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe180_p at 0x7fc463a6daf0>: -1.0,
#    <Metabolite 2agpe180_c at 0x7fc463a6dac0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPE181tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoethanolamine (n-C18:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR61'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpe181_p at 0x7fc463a6db50>: -1.0,
#    <Metabolite 2agpe181_c at 0x7fc463a6db20>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT120',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C12:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81336'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe120_c at 0x7fc463a6d910>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ddca_c at 0x7fc463a6dbb0>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe120_c at 0x7fc463a6dbe0>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT140',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C14:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81337'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe140_c at 0x7fc463a6d970>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ttdca_c at 0x7fc463a6dc70>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe140_c at 0x7fc463a6dc40>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT141',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C14:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR50741'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe141_c at 0x7fc463a6d9d0>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ttdcea_c at 0x7fc463a6dd00>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe141_c at 0x7fc463a6dca0>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT160',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C16:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68136', 'EC Number': '2.3.1.40'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe160_c at 0x7fc463a6da30>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite hdca_c at 0x7fc463a6dd60>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe160_c at 0x7fc463a6dd90>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT161',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C16:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81338'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe161_c at 0x7fc463a6da90>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite hdcea_c at 0x7fc463a6ddc0>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe161_c at 0x7fc463a6ddf0>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT180',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C18:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68137', 'EC Number': '2.3.1.40'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe180_c at 0x7fc463a6dac0>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ocdca_c at 0x7fc463a6de20>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe180_c at 0x7fc463a6de50>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPEAT181',
#   'name': '2-acyl-glycerophospho-ethanolamine acyltransferase (n-C18:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpe181_c at 0x7fc463a6db20>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ocdcea_c at 0x7fc463a6de80>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pe181_c at 0x7fc463a6deb0>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG120tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C12:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR69'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg120_p at 0x7fc463a6df10>: -1.0,
#    <Metabolite 2agpg120_c at 0x7fc463a6dee0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG140tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68139'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg140_p at 0x7fc463a6dd30>: -1.0,
#    <Metabolite 2agpg140_c at 0x7fc463a6df40>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG141tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C14:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR71'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg141_p at 0x7fc463a6df70>: -1.0,
#    <Metabolite 2agpg141_c at 0x7fc463a6dcd0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG160tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68140'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg160_p at 0x7fc463a6dfa0>: -1.0,
#    <Metabolite 2agpg160_c at 0x7fc463a6dfd0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG161tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C16:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR73'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg161_p at 0x7fc463adc160>: -1.0,
#    <Metabolite 2agpg161_c at 0x7fc463adc130>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG180tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:0) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68141'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg180_p at 0x7fc463adc0a0>: -1.0,
#    <Metabolite 2agpg180_c at 0x7fc463adc190>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPG181tipp',
#   'name': '2-Acyl-sn-glycero-3-phosphoglycerol (n-C18:1) transporter via facilitated diffusion (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR75'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite 2agpg181_p at 0x7fc463adc070>: -1.0,
#    <Metabolite 2agpg181_c at 0x7fc463adc040>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT120',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C12:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR76'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg120_c at 0x7fc463a6dee0>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ddca_c at 0x7fc463a6dbb0>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg120_c at 0x7fc4604a8d90>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT140',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C14:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68142'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg140_c at 0x7fc463a6df40>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ttdca_c at 0x7fc463a6dc70>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg140_c at 0x7fc463adc100>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT141',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C14:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR50742'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg141_c at 0x7fc463a6dcd0>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ttdcea_c at 0x7fc463a6dd00>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg141_c at 0x7fc463adc1c0>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT160',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C16:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68143'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg160_c at 0x7fc463a6dfd0>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite hdca_c at 0x7fc463a6dd60>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg160_c at 0x7fc463adc310>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT161',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C16:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68144'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg161_c at 0x7fc463adc130>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite hdcea_c at 0x7fc463a6ddc0>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg161_c at 0x7fc463adc220>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT180',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C18:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68145'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg180_c at 0x7fc463adc190>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ocdca_c at 0x7fc463a6de20>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg180_c at 0x7fc463adc250>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2AGPGAT181',
#   'name': '2-acyl-glycerophospho-glycerol acyltransferase (n-C18:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR82'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36256_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36256_1 at 0x7fc449820220>},
#   '_metabolites': {<Metabolite 2agpg181_c at 0x7fc463adc040>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite ocdcea_c at 0x7fc463a6de80>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite pg181_c at 0x7fc463adc280>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2HXMPt6',
#   'name': '2  hydroxymethyl phenol transport inout via proton symport',
#   'notes': {},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite h_e at 0x7fc463adc580>: -1.0,
#    <Metabolite 2hxmp_e at 0x7fc463adc6a0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0,
#    <Metabolite 2hxmp_c at 0x7fc463adc670>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2MAHMP',
#   'name': '2-Methyl-4-amino-5-hydroxymethylpyrimidine diphosphatase',
#   'notes': {'RHEA': '27914;27915;27916;27917',
#    'MetaNetX (MNX) Equation': 'MNXR68153',
#    'BioCyc': 'META:RXN0-3543'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU39211_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU39211_1 at 0x7fc449820310>},
#   '_metabolites': {<Metabolite 2mahmp_c at 0x7fc463adc700>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite 4ampm_c at 0x7fc463adc730>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0,
#    <Metabolite pi_c at 0x7fc463a6d100>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '2PGLYCt6',
#   'name': '2 Phosphoglycolate transport inout via proton symport',
#   'notes': {},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite h_e at 0x7fc463adc580>: -1.0,
#    <Metabolite 2pglyc_e at 0x7fc463adc7f0>: -1.0,
#    <Metabolite 2pglyc_c at 0x7fc463adc7c0>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD100',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C10:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68167',
#    'KEGG Reaction': 'R04535',
#    'EC Number': '4.2.1.59'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hdecACP_c at 0x7fc463adca00>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite tdec2eACP_c at 0x7fc463adcb80>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD120',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C12:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68168',
#    'KEGG Reaction': 'R04965',
#    'EC Number': '4.2.1.59'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hddecACP_c at 0x7fc463adca60>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite tddec2eACP_c at 0x7fc463adcbb0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD121',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C12:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68169', 'EC Number': '4.2.1.61'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hcddec5eACP_c at 0x7fc463adca90>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite t3c5ddeceACP_c at 0x7fc463adcbe0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD140',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C14:0)',
#   'notes': {'BioCyc': 'META:RXN-9537',
#    'MetaNetX (MNX) Equation': 'MNXR68170',
#    'KEGG Reaction': 'R04568',
#    'EC Number': '4.2.1.59'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hmrsACP_c at 0x7fc463adcac0>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite tmrs2eACP_c at 0x7fc463adcc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD141',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C14:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68171', 'EC Number': '4.2.1.61'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hcmrs7eACP_c at 0x7fc463adcaf0>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite t3c7mrseACP_c at 0x7fc463adcc40>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD160',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C16:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68172',
#    'KEGG Reaction': 'R04544',
#    'EC Number': '4.2.1.59'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hpalmACP_c at 0x7fc463adcc70>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite tpalm2eACP_c at 0x7fc463adcca0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD161',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C16:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68173', 'EC Number': '4.2.1.61'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hcpalm9eACP_c at 0x7fc463adccd0>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite t3c9palmeACP_c at 0x7fc463adcd00>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD180',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C18:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68174', 'EC Number': '4.2.1.61'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hoctaACP_c at 0x7fc463adcd30>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite toctd2eACP_c at 0x7fc463adcd60>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD181',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C18:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81364', 'EC Number': '4.2.1.61'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hcvac11eACP_c at 0x7fc463adcd90>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite t3c11vaceACP_c at 0x7fc463adcdc0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD40',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C4:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68176', 'EC Number': '4.2.1.58'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3haACP_c at 0x7fc463adcdf0>: -1.0,
#    <Metabolite but2eACP_c at 0x7fc463adce20>: 1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD60',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C6:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68177',
#    'KEGG Reaction': 'R04954',
#    'EC Number': '4.2.1.59'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hhexACP_c at 0x7fc463adcb20>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite thex2eACP_c at 0x7fc463adce50>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3HAD80',
#   'name': '3-hydroxyacyl-[acyl-carrier-protein] dehydratase (n-C8:0)',
#   'notes': {'BioCyc': 'META:4.2.1.59-RXN',
#    'MetaNetX (MNX) Equation': 'MNXR68178',
#    'KEGG Reaction': 'R04537',
#    'EC Number': '4.2.1.59'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38148_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38148_1 at 0x7fc449820280>},
#   '_metabolites': {<Metabolite 3hoctACP_c at 0x7fc463adcb50>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite toct2eACP_c at 0x7fc463adce80>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3MBtex',
#   'name': '3-methylbutanoic acid transport via diffusion (extracellular to periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81374'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36547_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36547_1 at 0x7fc4498201c0>},
#   '_metabolites': {<Metabolite 3mb_e at 0x7fc463adcf10>: -1.0,
#    <Metabolite 3mb_p at 0x7fc463adcfa0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR100',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C10:0)',
#   'notes': {'BioCyc': 'META:RXN-9528',
#    'MetaNetX (MNX) Equation': 'MNXR68183',
#    'KEGG Reaction': 'R04534',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3odecACP_c at 0x7fc463a82280>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hdecACP_c at 0x7fc463adca00>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR120',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C12:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68184',
#    'KEGG Reaction': 'R04964',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3oddecACP_c at 0x7fc463a822b0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hddecACP_c at 0x7fc463adca60>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR121',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C12:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR187', 'EC Number': '1.1.1.100'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ocddec5eACP_c at 0x7fc463a822e0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hcddec5eACP_c at 0x7fc463adca90>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR140',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C14:0)',
#   'notes': {'BioCyc': 'META:RXN-9536',
#    'MetaNetX (MNX) Equation': 'MNXR68185',
#    'KEGG Reaction': 'R04566',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3omrsACP_c at 0x7fc463a82310>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hmrsACP_c at 0x7fc463adcac0>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR141',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C14:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR189', 'EC Number': '1.1.1.100'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ocmrs7eACP_c at 0x7fc463a82340>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hcmrs7eACP_c at 0x7fc463adcaf0>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR160',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C16:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68186',
#    'KEGG Reaction': 'R04543',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3opalmACP_c at 0x7fc463a82370>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hpalmACP_c at 0x7fc463adcc70>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR161',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C16:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR191', 'EC Number': '1.1.1.100'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ocpalm9eACP_c at 0x7fc463a823a0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hcpalm9eACP_c at 0x7fc463adccd0>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR180',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C18:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR192', 'EC Number': '1.1.1.100'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ooctdACP_c at 0x7fc463a823d0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hoctaACP_c at 0x7fc463adcd30>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR181',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C18:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR23892',
#    'EC Number': '1.1.1.100',
#    'BioCyc': 'META:RXN-9556'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ocvac11eACP_c at 0x7fc463a82400>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hcvac11eACP_c at 0x7fc463adcd90>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR40',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C4:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68189', 'EC Number': '1.1.1.100'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite actACP_c at 0x7fc463a82430>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3haACP_c at 0x7fc463adcdf0>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR60',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C6:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR68190',
#    'KEGG Reaction': 'R04953',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ohexACP_c at 0x7fc463a82460>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hhexACP_c at 0x7fc463adcb20>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAR80',
#   'name': '3-oxoacyl-[acyl-carrier-protein] reductase (n-C8:0)',
#   'notes': {'BioCyc': 'META:RXN-9524',
#    'MetaNetX (MNX) Equation': 'MNXR68191',
#    'KEGG Reaction': 'R04536',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38145_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38145_1 at 0x7fc449820190>},
#   '_metabolites': {<Metabolite 3ooctACP_c at 0x7fc463a82490>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 3hoctACP_c at 0x7fc463adcb50>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS100',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C10:0)',
#   'notes': {'BioCyc': 'META:RXN-9527',
#    'MetaNetX (MNX) Equation': 'MNXR81380',
#    'KEGG Reaction': 'R04960',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite ocACP_c at 0x7fc463a824f0>: -1.0,
#    <Metabolite 3odecACP_c at 0x7fc463a82280>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS120',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C12:0)',
#   'notes': {'BioCyc': 'META:RXN-9531',
#    'MetaNetX (MNX) Equation': 'MNXR81381',
#    'KEGG Reaction': 'R04963',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite dcaACP_c at 0x7fc463a82520>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite 3oddecACP_c at 0x7fc463a822b0>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS121',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C12:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR47319', 'EC Number': '2.3.1.41'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite cdec3eACP_c at 0x7fc463a82550>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite 3ocddec5eACP_c at 0x7fc463a822e0>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS140',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C14:0)',
#   'notes': {'BioCyc': 'META:RXN-9535',
#    'MetaNetX (MNX) Equation': 'MNXR81382',
#    'KEGG Reaction': 'R04726',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite ddcaACP_c at 0x7fc463a82580>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite 3omrsACP_c at 0x7fc463a82310>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS141',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C14:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR47320', 'EC Number': '2.3.1.41'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite cddec5eACP_c at 0x7fc463a825b0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite 3ocmrs7eACP_c at 0x7fc463a82340>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS160',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C16:0)',
#   'notes': {'BioCyc': 'META:RXN-9539',
#    'MetaNetX (MNX) Equation': 'MNXR81383',
#    'KEGG Reaction': 'R04968',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite myrsACP_c at 0x7fc463a825e0>: -1.0,
#    <Metabolite 3opalmACP_c at 0x7fc463a82370>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS161',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C16:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR47321', 'EC Number': '2.3.1.41'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite tdeACP_c at 0x7fc463a82610>: -1.0,
#    <Metabolite 3ocpalm9eACP_c at 0x7fc463a823a0>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS180',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C18:0)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR48165', 'EC Number': '2.3.1.41'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite palmACP_c at 0x7fc463a82640>: -1.0,
#    <Metabolite 3ooctdACP_c at 0x7fc463a823d0>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS181',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C18:1)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR81384',
#    'EC Number': '2.3.1.179',
#    'BioCyc': 'META:2.3.1.179-RXN'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite hdeACP_c at 0x7fc463a82670>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite 3ocvac11eACP_c at 0x7fc463a82400>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS60',
#   'name': '3-oxoacyl-[acyl-carrier-protein] synthase (n-C6:0)',
#   'notes': {'BioCyc': 'META:RXN-9516',
#    'MetaNetX (MNX) Equation': 'MNXR81385',
#    'KEGG Reaction': 'R04952',
#    'EC Number': '2.3.1.86'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36255_1 or EDU38146_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36255_1 at 0x7fc4498202b0>,
#    <Gene EDU38146_1 at 0x7fc449820340>},
#   '_metabolites': {<Metabolite butACP_c at 0x7fc463a826a0>: -1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite malACP_c at 0x7fc463a824c0>: -1.0,
#    <Metabolite 3ohexACP_c at 0x7fc463a82460>: 1.0,
#    <Metabolite ACP_c at 0x7fc463adca30>: 1.0,
#    <Metabolite co2_c at 0x7fc463adc8e0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': '3OAS80',
# ...
#    <Metabolite moadcoo_c at 0x7fc448f74640>: -1.0,
#    <Metabolite moadamp_c at 0x7fc448f74430>: 1.0,
#    <Metabolite ppi_c at 0x7fc463a6dc10>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MSO3abc',
#   'name': 'Methanesulfonate transport via ABC system',
#   'notes': {},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36524_1 and EDU39295_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36524_1 at 0x7fc4498961f0>,
#    <Gene EDU39295_1 at 0x7fc44983bfa0>},
#   '_metabolites': {<Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite mso3_e at 0x7fc448f74670>: -1.0,
#    <Metabolite adp_c at 0x7fc463a6d160>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0,
#    <Metabolite mso3_c at 0x7fc448eefdc0>: 1.0,
#    <Metabolite pi_c at 0x7fc463a6d100>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MSO3abcpp',
#   'name': 'Methanesulfonate transport via ABC system (periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR3635'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36524_1 or EDU36526_1 or EDU39369_1 or EDU39370_1 or (EDU36524_1 and EDU36526_1) or (EDU36526_1 and EDU39167_1) or (EDU36526_1 and EDU39369_1) or (EDU36524_1 and EDU36526_1 and EDU39167_1) or (EDU39288_1 and EDU39293_1 and EDU39295_1)',
#   'subsystem': '',
#   '_genes': {<Gene EDU36524_1 at 0x7fc4498961f0>,
#    <Gene EDU36526_1 at 0x7fc449896070>,
#    <Gene EDU39167_1 at 0x7fc449896cd0>,
#    <Gene EDU39288_1 at 0x7fc449896250>,
#    <Gene EDU39293_1 at 0x7fc449896220>,
#    <Gene EDU39295_1 at 0x7fc44983bfa0>,
#    <Gene EDU39369_1 at 0x7fc449896100>,
#    <Gene EDU39370_1 at 0x7fc44983bfd0>},
#   '_metabolites': {<Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite mso3_p at 0x7fc448f746a0>: -1.0,
#    <Metabolite adp_c at 0x7fc463a6d160>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0,
#    <Metabolite mso3_c at 0x7fc448eefdc0>: 1.0,
#    <Metabolite pi_c at 0x7fc463a6d100>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MSO3tex',
#   'name': 'Methanesulfonate transport via diffusion (extracellular to periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR3636'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36547_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36547_1 at 0x7fc4498201c0>},
#   '_metabolites': {<Metabolite mso3_e at 0x7fc448f74670>: -1.0,
#    <Metabolite mso3_p at 0x7fc448f746a0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTAN',
#   'name': 'Methylthioadenosine nucleosidase',
#   'notes': {'EC Number': '3.2.2.9',
#    'BioCyc': 'META:METHYLTHIOADENOSINE-NUCLEOSIDASE-RXN',
#    'MetaNetX (MNX) Equation': 'MNXR3638',
#    'KEGG Reaction': 'R01401',
#    'RHEA': '13617;13618;13619;13620',
#    'UniPathway Reaction': 'UCR01401;UER00871'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37304_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37304_1 at 0x7fc449820f10>},
#   '_metabolites': {<Metabolite 5mta_c at 0x7fc463aae220>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite 5mtr_c at 0x7fc463aae280>: 1.0,
#    <Metabolite ade_c at 0x7fc463aae040>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTHFC',
#   'name': 'Methenyltetrahydrofolate cyclohydrolase',
#   'notes': {'RHEA': '23700;23701;23702;23703',
#    'MetaNetX (MNX) Equation': 'MNXR3641',
#    'KEGG Reaction': 'R01655',
#    'EC Number': '3.5.4.9'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37644_1 or EDU37645_1 or EDU38224_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37644_1 at 0x7fc4498a40d0>,
#    <Gene EDU37645_1 at 0x7fc4498a4040>,
#    <Gene EDU38224_1 at 0x7fc4498794f0>},
#   '_metabolites': {<Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite methf_c at 0x7fc45d380ac0>: -1.0,
#    <Metabolite 10fthf_c at 0x7fc463a377c0>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTHFD',
#   'name': 'Methylenetetrahydrofolate dehydrogenase (NADP)',
#   'notes': {'RHEA': '22812;22813;22814;22815',
#    'MetaNetX (MNX) Equation': 'MNXR3642',
#    'KEGG Reaction': 'R01220',
#    'EC Number': '1.5.1.5'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37644_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37644_1 at 0x7fc4498a40d0>},
#   '_metabolites': {<Metabolite mlthf_c at 0x7fc448eef130>: -1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: -1.0,
#    <Metabolite methf_c at 0x7fc45d380ac0>: 1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTHFR2',
#   'name': '5,10-methylenetetrahydrofolate reductase (NADH)',
#   'notes': {'RHEA': '19821;19822;19823;19824',
#    'MetaNetX (MNX) Equation': 'MNXR3644',
#    'KEGG Reaction': 'R07168',
#    'EC Number': '1.5.1.20'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37144_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37144_1 at 0x7fc4498a40a0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -2.0,
#    <Metabolite mlthf_c at 0x7fc448eef130>: -1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite 5mthf_c at 0x7fc463aae250>: 1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTHFR2_1',
#   'name': '5,10-methylenetetrahydrofolate reductase (NADH)',
#   'notes': {'RHEA': '19821;19822;19823;19824',
#    'MetaNetX (MNX) Equation': 'MNXR3644',
#    'KEGG Reaction': 'R07168',
#    'EC Number': '1.5.1.20'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37144_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37144_1 at 0x7fc4498a40a0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite mlthf_c at 0x7fc448eef130>: -1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite 5mthf_c at 0x7fc463aae250>: 1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTHFR3',
#   'name': '5 10 methylenetetrahydrofolatereductase  NADPH ',
#   'notes': {'RHEA': '19817;19818;19819;19820',
#    'MetaNetX (MNX) Equation': 'MNXR3645',
#    'KEGG Reaction': 'R01224',
#    'EC Number': '1.5.1.20'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37144_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37144_1 at 0x7fc4498a40a0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -2.0,
#    <Metabolite mlthf_c at 0x7fc448eef130>: -1.0,
#    <Metabolite nadph_c at 0x7fc45d375370>: -1.0,
#    <Metabolite 5mthf_c at 0x7fc463aae250>: 1.0,
#    <Metabolite nadp_c at 0x7fc463a6d790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTHTHFSs',
#   'name': '(2R,4S)-2-methyl-2,3,3,4-tetrahydroxytetrahydrofuran synthesis (spontaneous)',
#   'notes': {'RHEA': '35159;35160;35161;35162',
#    'MetaNetX (MNX) Equation': 'MNXR62125',
#    'BioCyc': 'META:RXN-10017'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'spontaneous',
#   'subsystem': '',
#   '_genes': {<Gene spontaneous at 0x7fc449820610>},
#   '_metabolites': {<Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite mdhdhf_c at 0x7fc448eef190>: -1.0,
#    <Metabolite mththf_c at 0x7fc448f74700>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTRI',
#   'name': '5-methylthioribose-1-phosphate isomerase',
#   'notes': {'EC Number': '5.3.1.23',
#    'BioCyc': 'META:5.3.1.23-RXN',
#    'MetaNetX (MNX) Equation': 'MNXR3650',
#    'KEGG Reaction': 'R04420',
#    'RHEA': '19989;19990;19991;19992',
#    'UniPathway Reaction': 'UCR04420;UER00874'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37540_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37540_1 at 0x7fc4498a4130>},
#   '_metabolites': {<Metabolite 5mdr1p_c at 0x7fc448f746d0>: -1.0,
#    <Metabolite 5mdru1p_c at 0x7fc448f74040>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'MTRK',
#   'name': '5-methylthioribose kinase',
#   'notes': {'EC Number': '2.7.1.100',
#    'BioCyc': 'META:5-METHYLTHIORIBOSE-KINASE-RXN',
#    'MetaNetX (MNX) Equation': 'MNXR3651',
#    'KEGG Reaction': 'R04143',
#    'RHEA': '22312;22313;22314;22315',
#    'UniPathway Reaction': 'UCR04143;UER00872'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU37541_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU37541_1 at 0x7fc4498a4160>},
#   '_metabolites': {<Metabolite 5mtr_c at 0x7fc463aae280>: -1.0,
#    <Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite adp_c at 0x7fc463a6d160>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0,
#    <Metabolite 5mdr1p_c at 0x7fc448f746d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'N2OR',
#   'name': 'Nitrous oxide reductase (nadh)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR29250', 'EC Number': '1.7.99.6'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite n2o_c at 0x7fc45d375550>: -1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: 1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0,
#    <Metabolite n2_c at 0x7fc448f74730>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'N2tex',
#   'name': 'Nitrogen exchange, diffusion (extra-organism to periplasm)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR3686'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36547_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36547_1 at 0x7fc4498201c0>},
#   '_metabolites': {<Metabolite n2_e at 0x7fc448f74760>: -1.0,
#    <Metabolite n2_p at 0x7fc448f74790>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NAabcO',
#   'name': 'Sodium transport out via ABC system',
#   'notes': {},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36532_1 and EDU36533_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36532_1 at 0x7fc4498a4340>,
#    <Gene EDU36533_1 at 0x7fc4498a4310>},
#   '_metabolites': {<Metabolite atp_c at 0x7fc463a6d250>: -1.0,
#    <Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite na1_c at 0x7fc463adc5e0>: -1.0,
#    <Metabolite adp_c at 0x7fc463a6d160>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 1.0,
#    <Metabolite pi_c at 0x7fc463a6d100>: 1.0,
#    <Metabolite na1_e at 0x7fc463adc610>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NACt',
#   'name': 'Nicotinic acid transport',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR3743'},
#   '_annotation': {},
#   '_gene_reaction_rule': '',
#   'subsystem': '',
#   '_genes': set(),
#   '_metabolites': {<Metabolite nac_e at 0x7fc448f747f0>: -1.0,
#    <Metabolite nac_c at 0x7fc448f747c0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NADDP',
#   'name': 'NAD diphosphatase',
#   'notes': {'EC Number': '3.6.1.9',
#    'BioCyc': 'META:NADPYROPHOSPHAT-RXN',
#    'BioPath Reaction': 'RXN00220',
#    'MetaNetX (MNX) Equation': 'MNXR3745',
#    'RHEA': '11800;11801;11802;11803',
#    'KEGG Reaction': 'R00103'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU38996_1 or EDU39274_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU38996_1 at 0x7fc4498a4190>,
#    <Gene EDU39274_1 at 0x7fc4498a41c0>},
#   '_metabolites': {<Metabolite h2o_c at 0x7fc463a6d430>: -1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: -1.0,
#    <Metabolite amp_c at 0x7fc463a6db80>: 1.0,
#    <Metabolite h_c at 0x7fc463a6d640>: 2.0,
#    <Metabolite nmn_c at 0x7fc448e74100>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NADFADOR',
#   'name': 'NAD:FAD oxidoreductase',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR83427'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU39259_1 or (EDU38860_1 and EDU39259_1)',
#   'subsystem': '',
#   '_genes': {<Gene EDU38860_1 at 0x7fc44986ac70>,
#    <Gene EDU39259_1 at 0x7fc44986aca0>},
#   '_metabolites': {<Metabolite fadh2_c at 0x7fc463a82bb0>: -1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: -2.0,
#    <Metabolite fdxr_42_c at 0x7fc463a82af0>: -1.0,
#    <Metabolite fad_c at 0x7fc463a82b80>: 1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: 2.0,
#    <Metabolite fdxo_42_c at 0x7fc463a82ac0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': -1000.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NADH10',
#   'name': 'NADH dehydrogenase (menaquinone-8 & 0 protons)',
#   'notes': {'RHEA': '29243;29244;29245;29246',
#    'MetaNetX (MNX) Equation': 'MNXR83428'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36458_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36458_1 at 0x7fc4498a41f0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite mqn8_c at 0x7fc448e74130>: -1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite mql8_c at 0x7fc448e49f70>: 1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NADH5',
#   'name': 'NADH dehydrogenase (ubiquinone-8 )',
#   'notes': {'RHEA': '29107;29108;29109;29110',
#    'MetaNetX (MNX) Equation': 'MNXR83430'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36458_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36458_1 at 0x7fc4498a41f0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite q8_c at 0x7fc448e749a0>: -1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0,
#    <Metabolite q8h2_c at 0x7fc448e749d0>: 1.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NADH6',
#   'name': 'NADH dehydrogenase (ubiquinone-8 & 3.5 protons)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR83431', 'EC Number': '1.6.5.3'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36458_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36458_1 at 0x7fc4498a41f0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -4.5,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite q8_c at 0x7fc448e749a0>: -1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0,
#    <Metabolite q8h2_c at 0x7fc448e749d0>: 1.0,
#    <Metabolite h_e at 0x7fc463adc580>: 3.5},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  {'_id': 'NADH7',
#   'name': 'NADH dehydrogenase (menaquinone-8 & 2 protons)',
#   'notes': {'MetaNetX (MNX) Equation': 'MNXR69516', 'EC Number': '1.6.5.3'},
#   '_annotation': {},
#   '_gene_reaction_rule': 'EDU36458_1',
#   'subsystem': '',
#   '_genes': {<Gene EDU36458_1 at 0x7fc4498a41f0>},
#   '_metabolites': {<Metabolite h_c at 0x7fc463a6d640>: -3.0,
#    <Metabolite mqn8_c at 0x7fc448e74130>: -1.0,
#    <Metabolite nadh_c at 0x7fc463a6d700>: -1.0,
#    <Metabolite mql8_c at 0x7fc448e49f70>: 1.0,
#    <Metabolite nad_c at 0x7fc463a6d6d0>: 1.0,
#    <Metabolite h_e at 0x7fc463adc580>: 2.0},
#   '_model': <Model Clostridium_sporogenes_ATCC_15579 at 0x7fc463a378e0>,
#   '_lower_bound': 0.0,
#   '_upper_bound': 1000.0},
#  ...]

# %%
# port reactions, to include genes and enzymes
def port_reaction(R):
    new = Reaction()
    new.id = R.id
    new.reactants = [remove_compartment_by_split(m.id,'_') for m in R.reactants] # decompartmentalization
    new.products = [remove_compartment_by_split(m.id,'_') for m in R.products]   # decompartmentalization
    new.genes = [g.id for g in R.genes]
    new.enzymes = R.notes.get('EC Number',[])
    new.db_ids = dict2listOfTuple(R.notes,';') # not sure ; is useful
    return new
    
test99 = port_reaction(model.reactions[200])
test99.__dict__
# Out:
# {'azimuth_id': '',
#  'id': 'ALAt2r',
#  'source': [],
#  'version': '',
#  'status': '',
#  'reactants': ['ala__L', 'h'],
#  'products': ['ala__L', 'h'],
#  'enzymes': [],
#  'genes': ['EDU37508_1', 'EDU36264_1', 'EDU37559_1'],
#  'pathways': [],
#  'ontologies': [],
#  'species': '',
#  'compartments': [],
#  'cell_types': [],
#  'tissues': [],
#  'db_ids': [('MetaNetX (MNX) Equation', 'MNXR636'),
#   ('BioCyc', 'META:RXN0-5202')]}

# %%
## Reactions to port
myRxns = []
for R in model.reactions:
    myRxns.append( port_reaction(R) )
    
print(len(myRxns))
# Out:
# 1715

# %%
# remove duplicated reactions after decompartmentalization
myRxns = remove_duplicate_rxn(myRxns)

# %%
len(myRxns)
# Out:
# 1457

# %%
myRxns[0].__dict__
# Out:
# {'azimuth_id': '',
#  'id': '2AGPEAT120',
#  'source': [],
#  'version': '',
#  'status': '',
#  'reactants': ['2agpe120', 'atp', 'ddca'],
#  'products': ['amp', 'pe120', 'ppi'],
#  'enzymes': [],
#  'genes': ['EDU36256_1'],
#  'pathways': [],
#  'ontologies': [],
#  'species': '',
#  'compartments': [],
#  'cell_types': [],
#  'tissues': [],
#  'db_ids': [('MetaNetX (MNX) Equation', 'MNXR81336')]}

# %% [markdown]
# ## Pathway information will be parsed later when looking back to the original data

# %% [markdown]
# ## Collected data; now output

# %%
from datetime import datetime
today =  str(datetime.today()).split(" ")[0]

# %%
today
# Out:
# '2022-04-27'

# %%
note = """CarveME model."""

## metabolicModel to export
MM = MetabolicModel()
MM.id = f'az_{model_name}_{today}' #
MM.meta_data = {
            'species': model_name.split('-')[0],
            'version': '',
            'sources': [f'https://github.com/SysBioChalmers/{model_name}, retrieved {today}'], #
            'status': '',
            'last_update': today,  #
            'note': note,
        }
# MM.list_of_pathways = [P.serialize() for P in myPathways]
MM.list_of_reactions = [R.serialize() for R in  myRxns]
MM.list_of_compounds = [C.serialize() for C in myCpds]

# %%
import pickle
import os

# Write pickle file
export_pickle(os.path.join(output_fdr,f'{MM.id}.pickle'), MM)

# %%
# Write json file
export_json(os.path.join(output_fdr,f'{MM.id}.json'), MM)

# %%
# Write dataframe 
import pandas as pd
export_table(os.path.join(output_fdr,f'{MM.id}_list_of_compounds.csv'),MM, 'list_of_compounds')
export_table(os.path.join(output_fdr,f'{MM.id}_list_of_reactions.csv'),MM, 'list_of_reactions')
# export_table(os.path.join(output_fdr,f'{MM.id}_list_of_pathways.csv'),MM, 'list_of_pathways')

# %% [markdown]
# ## Summary
#
# This ports reactions, pathways and compounds. Gene and enzyme information is now included.
#
# The exported pickle can be re-imported and uploaded to Database easily.
#
# This notebook, the pickle file and the JSON file go to GitHub repo (https://github.com/shuzhao-li/Azimuth).
